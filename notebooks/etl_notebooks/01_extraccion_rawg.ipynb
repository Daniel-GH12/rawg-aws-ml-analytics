# %%
import requests
import json
from datetime import datetime, timedelta
from time import sleep
import time

# %%
# %run ../bootstrap.py

import utils.secrets as s

# %%
# === EXTRACIÓN HISTÓRICO DATOS DESDE 01-01-2016 HASTA 26-01-2026 ===

# Configuración
from utils.secrets import get_rawg_api_key_cached

API_KEY = get_rawg_api_key_cached()
base_url = f"https://api.rawg.io/api/games"

resultados = []
errores = []

# Calcular días desde 2016-01-01 hasta hoy
fecha_inicio = datetime(2016, 1, 1)
dias_total = (datetime.now() - fecha_inicio).days

print(f"Extrayendo datos desde {fecha_inicio.strftime('%Y-%m-%d')} hasta hoy")
print(f"Total de días a procesar: {dias_total}\n")

for i in range(dias_total):
    
    fecha = (datetime(2016, 1, 1) + timedelta(days = i)).strftime("%Y-%m-%d")
    
    params = {
        "key"       : API_KEY,
        "page_size" : 40,
        "dates"     : f"{fecha},{fecha}"
    }

    try: 
        # Hacer la petición
        response = requests.get(base_url, params = params)
            
        if response.status_code == 200:
            data = response.json()
            count = data["count"]
            juegos = data["results"]
            
            print(f"{fecha}: {count} juegos encontrados", end = "\t")
        
            resultados.extend(juegos)
        
        else:
            print(f"Error:{response.status_code} en {fecha}")
            errores.append({"fecha": fecha, "status": response.status_code})
        
        # Rate limiting 
        sleep(1)

        
    except requests.exceptions.Timeout:
        print(f"\nTimeout en {fecha}")
        errores.append({"fecha": fecha, "error": "timeout"})
        sleep(5)
            
    except Exception as e:
        print(f"\nError inesperado en {fecha}: {e}")
        errores.append({"fecha": fecha, "error": str(e)})

print(f"\n\nEXTRACCIÓN COMPLETADA")
print(f"Juegos extraídos: {len(resultados)}")
print(f"Errores encontrados: {len(errores)}")

# %%
# ==== GUARDAR EXTRACCIÓN HISTÓRICA ====

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
nombre_archivo = f"C:/Users/crisr/dev/rawg-aws-ml-analytics/notas_cris/00_data/extraccion_historica_{timestamp}.json"

with open(nombre_archivo, mode = "w", encoding = "utf-8") as file:
    json.dump(resultados, file, indent=2, ensure_ascii=False)

print(f"Datos guardados en {nombre_archivo}")

# %%
# === EXTRACIÓN HISTÓRICO DATOS DESDE 01-01-2016 HASTA 26-01-2026 (8 días) ===

# Configuración
from utils.secrets import get_rawg_api_key_cached

API_KEY = get_rawg_api_key_cached()
base_url = f"https://api.rawg.io/api/games"
resultados = []
errores = []

# Calcular días desde 2016-01-01 hasta hoy
fecha_inicio = datetime(2026, 1, 20)
dias_total = (datetime.now() - fecha_inicio).days

print(f"Extrayendo datos desde {fecha_inicio.strftime('%Y-%m-%d')} hasta hoy")
print(f"Total de días a procesar: {dias_total}\n")

for i in range(dias_total):
    
    fecha = (datetime(2016, 1, 1) + timedelta(days = i)).strftime("%Y-%m-%d")
    
    params = {
        "key"       : API_KEY,
        "page_size" : 40,
        "dates"     : f"{fecha},{fecha}"
    }

    try: 
        # Hacer la petición
        response = requests.get(base_url, params = params)
            
        if response.status_code == 200:
            data = response.json()
            count = data["count"]
            juegos = data["results"]
            
            print(f"{fecha}: {count} juegos encontrados", end = "\t")
        
            resultados.extend(juegos)
        
        else:
           print(f"Error:{response.status_code} en {fecha}")
           errores.append({"fecha": fecha, "status": response.status_code})
        
        # Rate limiting 
        sleep(1)

        
    except requests.exceptions.Timeout:
        print(f"\nTimeout en {fecha}")
        errores.append({"fecha": fecha, "error": "timeout"})
        sleep(5)
            
    except Exception as e:
        print(f"\nError inesperado en {fecha}: {e}")
        errores.append({"fecha": fecha, "error": str(e)})

print(f"\n\nEXTRACCIÓN COMPLETADA")
print(f"Juegos extraídos: {len(resultados)}")
print(f"Errores encontrados: {len(errores)}")
# Out:
# Extrayendo datos desde 2026-01-20 hasta hoy
# Total de días a procesar: 14
#
# 2016-01-01: 62 juegos encontrados	2016-01-02: 55 juegos encontrados	2016-01-03: 51 juegos encontrados	2016-01-04: 89 juegos encontrados	2016-01-05: 75 juegos encontrados	2016-01-06: 93 juegos encontrados	2016-01-07: 96 juegos encontrados	2016-01-08: 88 juegos encontrados	2016-01-09: 82 juegos encontrados	2016-01-10: 85 juegos encontrados	2016-01-11: 83 juegos encontrados	2016-01-12: 69 juegos encontrados	2016-01-13: 78 juegos encontrados	2016-01-14: 123 juegos encontrados
#
# EXTRACCIÓN COMPLETADA
# Juegos extraídos: 560
# Errores encontrados: 0

# %%
# ==== GUARDAR EXTRACCIÓN 8 DÍAS ====
import os

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
nombre_archivo = f"C:/Users/crisr/dev/rawg-aws-ml-analytics/notas_cris/00_data/extraccion_8dias_{timestamp}.json"

with open(nombre_archivo, mode = "w", encoding = "utf-8") as file:
    json.dump(resultados, file, indent=2, ensure_ascii=False)

print(f"Datos guardados en {nombre_archivo}")
# Out:
# Datos guardados en C:/Users/crisr/dev/rawg-aws-ml-analytics/notas_cris/00_data/extraccion_8dias_20260204_000152.json
